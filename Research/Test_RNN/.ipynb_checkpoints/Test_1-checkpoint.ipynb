# %%
import numpy as np
import pandas as pd
import seaborn as sb
from sklearn import tree
from sklearn import ensemble
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# %%
dataset = pd.read_csv('data.csv')
y = dataset['Diagnosis'] # Dedendent Variable
x = dataset.drop(['ID ','Diagnosis'], axis = 1) # Independent Variable
dataset.head()
# Out:
#         ID  Diagnosis  radius_mean  texture_mean  permeter_mean  area_mean  \
# 0    842302         M        17.99         10.38         122.80     1001.0
# 1    842517         M        20.57         17.77         132.90     1326.0
# 2  84300903         M        19.69         21.25         130.00     1203.0
# 3  84348301         M        11.42         20.38          77.58      386.1
# 4  84358402         M        20.29         14.34         135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  adius_worst  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
x.isnull().sum()
# Out:
# radius_mean                  0
# texture_mean                 0
# permeter_mean                0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave_points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave_points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# adius_worst                  0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave_points_worst         0
# symmetry_worst               0
# fractional_dimension_mean    0
# ...

# %%
# independent = dataset.iloc[:,2:29]
# dependent = dataset.iloc[:,1]
x.head()
# Out:
#    radius_mean  texture_mean  permeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38         122.80     1001.0          0.11840
# 1        20.57         17.77         132.90     1326.0          0.08474
# 2        19.69         21.25         130.00     1203.0          0.10960
# 3        11.42         20.38          77.58      386.1          0.14250
# 4        20.29         14.34         135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave_points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  adius_worst  texture_worst  perimeter_worst  \
# ...

# %%
# X and Y variables for test and train

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=2) # Test Size is 25%

# %%
# x_train
# x_test
# y_train
# y_test

# %%
# Simple Decision Tree

DTclf = DecisionTreeClassifier(max_depth=5)
DTclf.fit(x_train,y_train) # Train
DTclf.score(x_test,y_test) # Test
y_pred = DTclf.predict(x_test)
DTclf.score(x_test,y_test)
# Out:
# 0.958041958041958

# %%
# Random Forest Classifier

RFclf = ensemble.RandomForestClassifier(n_estimators=150)
RFclf.fit(x_train,y_train) # Train
RFclf.score(x_test,y_test) # Test
# Out:
# 0.9370629370629371

# %%
# Logistic Regression

LRmodel = LogisticRegression(max_iter=500)
# clf.fit(x_train,y_train)
LRmodel.fit(x_train,y_train) # Train
LRmodel.score(x_test,y_test) # Test
# Out:
# 0.9370629370629371
